# %% [markdown]
# # Predicting Boston Housing Prices
#
# ## Updating a model using SageMaker
#
# _Deep Learning Nanodegree Program | Deployment_
#
# ---
#
# In this notebook, we will continue working with the [Boston Housing Dataset](https://www.cs.toronto.edu/~delve/data/boston/bostonDetail.html). Our goal in this notebook will be to train two different models and to use SageMaker to switch a deployed endpoint from using one model to the other. One of the benefits of using SageMaker to do this is that we can make the change without interrupting service. What this means is that we can continue sending data to the endpoint and at no point will that endpoint disappear.
#
# ## General Outline
#
# Typically, when using a notebook instance with SageMaker, you will proceed through the following steps. Of course, not every step will need to be done with each project. Also, there is quite a lot of room for variation in many of the steps, as you will see throughout these lessons.
#
# 1. Download or otherwise retrieve the data.
# 2. Process / Prepare the data.
# 3. Upload the processed data to S3.
# 4. Train a chosen model.
# 5. Test the trained model (typically using a batch transform job).
# 6. Deploy the trained model.
# 7. Use the deployed model.
#
# In this notebook we will be skipping step 5, testing the model. In addition, we will perform steps 4, 6 and 7 multiple times with different models.

# %%
# Make sure that we use SageMaker 1.x
# !pip install sagemaker==1.72.0
# Out:
# Requirement already satisfied: sagemaker==1.72.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (1.72.0)
# Requirement already satisfied: boto3>=1.14.12 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (1.17.35)
# Requirement already satisfied: packaging>=20.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (20.9)
# Requirement already satisfied: numpy>=1.9.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (1.19.5)
# Requirement already satisfied: protobuf>=3.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (3.15.2)
# Requirement already satisfied: importlib-metadata>=1.4.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (3.7.0)
# Requirement already satisfied: scipy>=0.19.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (1.5.3)
# Requirement already satisfied: protobuf3-to-dict>=0.1.5 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (0.1.5)
# Requirement already satisfied: smdebug-rulesconfig==0.1.4 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from sagemaker==1.72.0) (0.1.4)
# Requirement already satisfied: botocore<1.21.0,>=1.20.35 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from boto3>=1.14.12->sagemaker==1.72.0) (1.20.35)
# Requirement already satisfied: s3transfer<0.4.0,>=0.3.0 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from boto3>=1.14.12->sagemaker==1.72.0) (0.3.4)
# Requirement already satisfied: jmespath<1.0.0,>=0.7.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from boto3>=1.14.12->sagemaker==1.72.0) (0.10.0)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.35->boto3>=1.14.12->sagemaker==1.72.0) (2.8.1)
# Requirement already satisfied: urllib3<1.27,>=1.25.4 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from botocore<1.21.0,>=1.20.35->boto3>=1.14.12->sagemaker==1.72.0) (1.26.3)
# Requirement already satisfied: zipp>=0.5 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker==1.72.0) (3.4.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from importlib-metadata>=1.4.0->sagemaker==1.72.0) (3.7.4.3)
# Requirement already satisfied: pyparsing>=2.0.2 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from packaging>=20.0->sagemaker==1.72.0) (2.4.7)
# Requirement already satisfied: six>=1.9 in /home/ec2-user/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages (from protobuf>=3.1->sagemaker==1.72.0) (1.15.0)

# %% [markdown]
# ## Step 0: Setting up the notebook
#
# We begin by setting up all of the necessary bits required to run our notebook. To start that means loading all of the Python modules we will need.

# %%
# %matplotlib inline

import os

import numpy as np
import pandas as pd

from pprint import pprint
import matplotlib.pyplot as plt
from time import gmtime, strftime

from sklearn.datasets import load_boston
import sklearn.model_selection

# %% [markdown]
# In addition to the modules above, we need to import the various bits of SageMaker that we will be using.

# %%
import sagemaker
from sagemaker import get_execution_role
from sagemaker.amazon.amazon_estimator import get_image_uri
from sagemaker.predictor import csv_serializer

# This is an object that represents the SageMaker session that we are currently operating in. This
# object contains some useful information that we will need to access later such as our region.
session = sagemaker.Session()

# This is an object that represents the IAM role that we are currently assigned. When we construct
# and launch the training job later we will need to tell it what IAM role it should have. Since our
# use case is relatively simple we will simply assign the training job the role we currently have.
role = get_execution_role()

# %% [markdown]
# ## Step 1: Downloading the data
#
# Fortunately, this dataset can be retrieved using sklearn and so this step is relatively straightforward.

# %%
boston = load_boston()

# %% [markdown]
# ## Step 2: Preparing and splitting the data
#
# Given that this is clean tabular data, we don't need to do any processing. However, we do need to split the rows in the dataset up into train, test and validation sets.

# %%
# First we package up the input data and the target variable (the median value) as pandas dataframes. This
# will make saving the data to a file a little easier later on.

X_bos_pd = pd.DataFrame(boston.data, columns=boston.feature_names)
Y_bos_pd = pd.DataFrame(boston.target)

# We split the dataset into 2/3 training and 1/3 testing sets.
X_train, X_test, Y_train, Y_test = sklearn.model_selection.train_test_split(X_bos_pd, Y_bos_pd, test_size=0.33)

# Then we split the training set further into 2/3 training and 1/3 validation sets.
X_train, X_val, Y_train, Y_val = sklearn.model_selection.train_test_split(X_train, Y_train, test_size=0.33)

# %% [markdown]
# ## Step 3: Uploading the training and validation files to S3
#
# When a training job is constructed using SageMaker, a container is executed which performs the training operation. This container is given access to data that is stored in S3. This means that we need to upload the data we want to use for training to S3. We can use the SageMaker API to do this and hide some of the details.
#
# ### Save the data locally
#
# First we need to create the train and validation csv files which we will then upload to S3.

# %%
# This is our local data directory. We need to make sure that it exists.
data_dir = '../data/boston'
if not os.path.exists(data_dir):
    os.makedirs(data_dir)

# %%
# We use pandas to save our train and validation data to csv files. Note that we make sure not to include header
# information or an index as this is required by the built in algorithms provided by Amazon. Also, it is assumed
# that the first entry in each row is the target variable.

pd.concat([Y_val, X_val], axis=1).to_csv(os.path.join(data_dir, 'validation.csv'), header=False, index=False)
pd.concat([Y_train, X_train], axis=1).to_csv(os.path.join(data_dir, 'train.csv'), header=False, index=False)

# %% [markdown]
# ### Upload to S3
#
# Since we are currently running inside of a SageMaker session, we can use the object which represents this session to upload our data to the 'default' S3 bucket. Note that it is good practice to provide a custom prefix (essentially an S3 folder) to make sure that you don't accidentally interfere with data uploaded from some other notebook or project.

# %%
prefix = 'boston-update-endpoints'

val_location = session.upload_data(os.path.join(data_dir, 'validation.csv'), key_prefix=prefix)
train_location = session.upload_data(os.path.join(data_dir, 'train.csv'), key_prefix=prefix)

# %% [markdown]
# ## Step 4 (A): Train the XGBoost model
#
# Now that we have the training and validation data uploaded to S3, we can construct our XGBoost model and train it. We will be making use of the high level SageMaker API to do this which will make the resulting code a little easier to read at the cost of some flexibility.
#
# To construct an estimator, the object which we wish to train, we need to provide the location of a container which contains the training code. Since we are using a built in algorithm this container is provided by Amazon. However, the full name of the container is a bit lengthy and depends on the region that we are operating in. Fortunately, SageMaker provides a useful utility method called `get_image_uri` that constructs the image name for us.
#
# To use the `get_image_uri` method we need to provide it with our current region, which can be obtained from the session object, and the name of the algorithm we wish to use. In this notebook we will be using XGBoost however you could try another algorithm if you wish. The list of built in algorithms can be found in the list of [Common Parameters](https://docs.aws.amazon.com/sagemaker/latest/dg/sagemaker-algo-docker-registry-paths.html).

# %%
# As stated above, we use this utility method to construct the image name for the training container.
xgb_container = get_image_uri(session.boto_region_name, 'xgboost')

# Now that we know which container to use, we can construct the estimator object.
xgb = sagemaker.estimator.Estimator(xgb_container, # The name of the training container
                                    role,      # The IAM role to use (our current role in this case)
                                    train_instance_count=1, # The number of instances to use for training
                                    train_instance_type='ml.m4.xlarge', # The type of instance ot use for training
                                    output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                                                        # Where to save the output (the model artifacts)
                                    sagemaker_session=session) # The current SageMaker session
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# There is a more up to date SageMaker XGBoost image. To use the newer image, please set 'repo_version'='1.0-1'. For example:
# 	get_image_uri(region, 'xgboost', '1.0-1').
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# Before asking SageMaker to begin the training job, we should probably set any model specific hyperparameters. There are quite a few that can be set when using the XGBoost algorithm, below are just a few of them. If you would like to change the hyperparameters below or modify additional ones you can find additional information on the [XGBoost hyperparameter page](https://docs.aws.amazon.com/sagemaker/latest/dg/xgboost_hyperparameters.html)

# %%
xgb.set_hyperparameters(max_depth=5,
                        eta=0.2,
                        gamma=4,
                        min_child_weight=6,
                        subsample=0.8,
                        objective='reg:linear',
                        early_stopping_rounds=10,
                        num_round=200)

# %% [markdown]
# Now that we have our estimator object completely set up, it is time to train it. To do this we make sure that SageMaker knows our input data is in csv format and then execute the `fit` method.

# %%
# This is a wrapper around the location of our train and validation data, to make sure that SageMaker
# knows our data is in csv format.
s3_input_train = sagemaker.s3_input(s3_data=train_location, content_type='text/csv')
s3_input_validation = sagemaker.s3_input(s3_data=val_location, content_type='text/csv')

######## We call "fit" to fit our model to the training and validation data ###########
######## The result of calling the fit method is that model artifacts have been created
xgb.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# 2021-04-23 04:14:09 Starting - Starting the training job...
# 2021-04-23 04:14:13 Starting - Launching requested ML instances......
# 2021-04-23 04:15:16 Starting - Preparing the instances for training......
# 2021-04-23 04:16:26 Downloading - Downloading input data......
# 2021-04-23 04:17:38 Training - Training image download completed. Training in progress.
# 2021-04-23 04:17:38 Uploading - Uploading generated training model.Arguments: train
# [2021-04-23:04:17:34:INFO] Running standalone xgboost training.
# [2021-04-23:04:17:34:INFO] File size need to be processed in the node: 0.02mb. Available memory size in the node: 8430.8mb
# [2021-04-23:04:17:34:INFO] Determined delimiter of CSV input is ','
# [04:17:34] S3DistributionType set as FullyReplicated
# [04:17:34] 227x13 matrix with 2951 entries loaded from /opt/ml/input/data/train?format=csv&label_column=0&delimiter=,
# [2021-04-23:04:17:34:INFO] Determined delimiter of CSV input is ','
# [04:17:34] S3DistributionType set as FullyReplicated
# [04:17:34] 112x13 matrix with 1456 entries loaded from /opt/ml/input/data/validation?format=csv&label_column=0&delimiter=,
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 8 extra nodes, 0 pruned nodes, max_depth=3
# [0]#011train-rmse:18.8895#011validation-rmse:20.3485
# Multiple eval metrics have been passed: 'validation-rmse' will be used for early stopping.
#
# Will train until validation-rmse hasn't improved in 10 rounds.
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=3
# [1]#011train-rmse:15.4559#011validation-rmse:16.7462
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=3
# [2]#011train-rmse:12.7066#011validation-rmse:13.8715
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=4
# [3]#011train-rmse:10.5378#011validation-rmse:11.6869
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 4 pruned nodes, max_depth=4
# [4]#011train-rmse:8.7979#011validation-rmse:9.8988
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=5
# [5]#011train-rmse:7.48518#011validation-rmse:8.56377
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 0 pruned nodes, max_depth=5
# [6]#011train-rmse:6.41364#011validation-rmse:7.4862
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 30 extra nodes, 2 pruned nodes, max_depth=5
# [7]#011train-rmse:5.483#011validation-rmse:6.55911
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [8]#011train-rmse:4.72698#011validation-rmse:5.89996
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 26 extra nodes, 2 pruned nodes, max_depth=5
# [9]#011train-rmse:4.14096#011validation-rmse:5.43095
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [10]#011train-rmse:3.7528#011validation-rmse:5.09398
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [11]#011train-rmse:3.45818#011validation-rmse:4.8019
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [12]#011train-rmse:3.15219#011validation-rmse:4.58029
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [13]#011train-rmse:2.90441#011validation-rmse:4.45476
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [14]#011train-rmse:2.71585#011validation-rmse:4.27261
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [15]#011train-rmse:2.54929#011validation-rmse:4.10737
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 4 pruned nodes, max_depth=5
# [16]#011train-rmse:2.44179#011validation-rmse:4.10115
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 2 pruned nodes, max_depth=5
# [17]#011train-rmse:2.33864#011validation-rmse:4.00939
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 0 pruned nodes, max_depth=5
# [18]#011train-rmse:2.26784#011validation-rmse:3.91954
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [19]#011train-rmse:2.20769#011validation-rmse:3.87215
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [20]#011train-rmse:2.14293#011validation-rmse:3.83552
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 2 pruned nodes, max_depth=5
# [21]#011train-rmse:2.11141#011validation-rmse:3.78493
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [22]#011train-rmse:2.04606#011validation-rmse:3.75113
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 0 pruned nodes, max_depth=5
# [23]#011train-rmse:1.99559#011validation-rmse:3.72251
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [24]#011train-rmse:1.90547#011validation-rmse:3.64342
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 4 pruned nodes, max_depth=5
# [25]#011train-rmse:1.86371#011validation-rmse:3.65352
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [26]#011train-rmse:1.85551#011validation-rmse:3.65869
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 28 extra nodes, 0 pruned nodes, max_depth=5
# [27]#011train-rmse:1.81461#011validation-rmse:3.68054
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [28]#011train-rmse:1.79473#011validation-rmse:3.67749
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 12 extra nodes, 0 pruned nodes, max_depth=5
# [29]#011train-rmse:1.77472#011validation-rmse:3.66868
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 2 pruned nodes, max_depth=5
# [30]#011train-rmse:1.75023#011validation-rmse:3.66796
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 6 pruned nodes, max_depth=5
# [31]#011train-rmse:1.69766#011validation-rmse:3.63917
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 16 extra nodes, 14 pruned nodes, max_depth=5
# [32]#011train-rmse:1.64768#011validation-rmse:3.61752
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 0 pruned nodes, max_depth=5
# [33]#011train-rmse:1.62241#011validation-rmse:3.63735
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 8 pruned nodes, max_depth=5
# [34]#011train-rmse:1.59825#011validation-rmse:3.63032
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 0 pruned nodes, max_depth=5
# [35]#011train-rmse:1.53529#011validation-rmse:3.65827
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 22 extra nodes, 0 pruned nodes, max_depth=5
# [36]#011train-rmse:1.51396#011validation-rmse:3.66807
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 18 extra nodes, 4 pruned nodes, max_depth=5
# [37]#011train-rmse:1.49196#011validation-rmse:3.65838
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 14 extra nodes, 6 pruned nodes, max_depth=5
# [38]#011train-rmse:1.46144#011validation-rmse:3.63321
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 6 extra nodes, 18 pruned nodes, max_depth=2
# [39]#011train-rmse:1.43155#011validation-rmse:3.6334
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 2 pruned nodes, max_depth=5
# [40]#011train-rmse:1.38635#011validation-rmse:3.62889
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 20 extra nodes, 10 pruned nodes, max_depth=5
# [41]#011train-rmse:1.35817#011validation-rmse:3.65635
# [04:17:34] src/tree/updater_prune.cc:74: tree pruning end, 1 roots, 10 extra nodes, 2 pruned nodes, max_depth=5
# [42]#011train-rmse:1.34365#011validation-rmse:3.64419
# Stopping. Best iteration:
# [32]#011train-rmse:1.64768#011validation-rmse:3.61752
#
#
# 2021-04-23 04:17:45 Completed - Training job completed
# Training seconds: 79
# Billable seconds: 79

# %% [markdown]
# ## Step 5: Test the trained model
#
# We will be skipping this step for now.
#
#
# ## Step 6 (A): Deploy the trained model
#
# Even though we used the high level approach to construct and train the XGBoost model, we will be using the lower level approach to deploy it. One of the reasons for this is so that we have additional control over how the endpoint is constructed. This will be a little more clear later on when construct more advanced endpoints.
#
# ### Build the model
#
# Of course, before we can deploy the model, we need to first create it. The `fit` method that we used earlier created some model artifacts and we can use these to construct a model object.

# %%
# Remember that a model needs to have a unique name
xgb_model_name = "boston-update-xgboost-model" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# We also need to tell SageMaker which container should be used for inference and where it should
# retrieve the model artifacts from. In our case, the xgboost container that we used for training
# can also be used for inference and the model artifacts come from the previous call to fit.
######### Set up the data structure:
xgb_primary_container = {
    "Image": xgb_container,  ###### which container should be used for inference
    "ModelDataUrl": xgb.model_data  ###### model artifacts that we have created earlier
}

# And lastly we construct the SageMaker model
######## And then we can ask Sagemake to create the model
xgb_model_info = session.sagemaker_client.create_model(
                                ModelName = xgb_model_name,
                                ExecutionRoleArn = role,
                                PrimaryContainer = xgb_primary_container)

# %% [markdown]
# ### Create the endpoint configuration
#
# Once we have a model we can start putting together the endpoint. Recall that to do this we need to first create an endpoint configuration, essentially the blueprint that SageMaker will use to build the endpoint itself.

# %%
######## Once we have a model, we can create an endpoint configuration 


# As before, we need to give our endpoint configuration a name which should be unique
xgb_endpoint_config_name = "boston-update-xgboost-endpoint-config-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we ask SageMaker to construct the endpoint configuration
xgb_endpoint_config_info = session.sagemaker_client.create_endpoint_config(
                            EndpointConfigName = xgb_endpoint_config_name,
                            ProductionVariants = [{
                                "InstanceType": "ml.m4.xlarge",
                                "InitialVariantWeight": 1,
                                "InitialInstanceCount": 1,
                                "ModelName": xgb_model_name,
                                "VariantName": "XGB-Model"
                            }])

# %% [markdown]
# ### Deploy the endpoint
#
# Now that the endpoint configuration has been created, we can ask SageMaker to build our endpoint.
#
# **Note:** This is a friendly (repeated) reminder that you are about to deploy an endpoint. Make sure that you shut it down once you've finished with it!

# %%
####### Once we have an endpoint configuration, we can ask SageMaker to create an endpoint with those properties

# Again, we need a unique name for our endpoint
endpoint_name = "boston-update-endpoint-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we can deploy our endpoint
endpoint_info = session.sagemaker_client.create_endpoint(
                    EndpointName = endpoint_name,
                    EndpointConfigName = xgb_endpoint_config_name)

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)
# Out:
# -------------!

# %% [markdown]
# ## Step 7 (A): Use the model
#
# Now that our model is trained and deployed we can send some test data to it and evaluate the results.

# %%
######## We can test our endpoint to make sure it's working

response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[0]))) ####### we serialize the input data 
                                                                ####### and sent it off to our endpoint

# %%
pprint(response)
# Out:
# {'Body': <botocore.response.StreamingBody object at 0x7fbe86d5aa58>,
#  'ContentType': 'text/csv; charset=utf-8',
#  'InvokedProductionVariant': 'XGB-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '17',
#                                       'content-type': 'text/csv; charset=utf-8',
#                                       'date': 'Fri, 23 Apr 2021 04:24:54 GMT',
#                                       'x-amzn-invoked-production-variant': 'XGB-Model',
#                                       'x-amzn-requestid': '5d4d4297-ebd4-492a-8791-b8f46e127879'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '5d4d4297-ebd4-492a-8791-b8f46e127879',
#                       'RetryAttempts': 0}}

# %%
result = response['Body'].read().decode("utf-8") ### we need to convert the bit stream into a string which we can use the decode
                                ##### method to do it

# %%
pprint(result)
# Out:
# '46.70244216918945'

# %%
Y_test.values[0]
# Out:
# array([48.5])

# %% [markdown]
# ## Shut down the endpoint
#
# Now that we know that the XGBoost endpoint works, we can shut it down. We will make use of it again later.

# %%
session.sagemaker_client.delete_endpoint(EndpointName = endpoint_name)
# Out:
# {'ResponseMetadata': {'RequestId': 'a91e7467-7cbe-4fbb-9799-4c2808278836',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': 'a91e7467-7cbe-4fbb-9799-4c2808278836',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Fri, 23 Apr 2021 04:24:53 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## Step 4 (B): Train the Linear model
#
# Suppose we are working in an environment where the XGBoost model that we trained earlier is becoming too costly. Perhaps the number of calls to our endpoint has increased and the length of time it takes to perform inference with the XGBoost model is becoming problematic.
#
# A possible solution might be to train a simpler model to see if it performs nearly as well. In our case, we will construct a linear model. The process of doing this is the same as for creating the XGBoost model that we created earlier, although there are different hyperparameters that we need to set.

# %%
######### We create a linear model in much the same way as we create XGBoost model ##########


# Similar to the XGBoost model, we will use the utility method to construct the image name for the training container.
linear_container = get_image_uri(session.boto_region_name, 'linear-learner')

# Now that we know which container to use, we can construct the estimator object.
####### We will start by using the high level approach to create the model aitifacts, which can be done by creating an 
####### estimator object

linear = sagemaker.estimator.Estimator(linear_container, # The name of the training container
                                        role,      # The IAM role to use (our current role in this case)
                                        train_instance_count=1, # The number of instances to use for training
                                        train_instance_type='ml.m4.xlarge', # The type of instance ot use for training
                                        output_path='s3://{}/{}/output'.format(session.default_bucket(), prefix),
                                                                            # Where to save the output (the model artifacts)
                                        sagemaker_session=session) # The current SageMaker session
# Out:
# 'get_image_uri' method will be deprecated in favor of 'ImageURIProvider' class in SageMaker Python SDK v2.
# Parameter image_name will be renamed to image_uri in SageMaker Python SDK v2.

# %% [markdown]
# Before asking SageMaker to train our model, we need to set some hyperparameters. In this case we will be using a linear model so the number of hyperparameters we need to set is much fewer. For more details see the [Linear model hyperparameter page](https://docs.aws.amazon.com/sagemaker/latest/dg/ll_hyperparameters.html)

# %%
######## We set some hyperparameters specific to the algorithm
linear.set_hyperparameters(feature_dim=13, # Our data has 13 feature columns
                           predictor_type='regressor', # We wish to create a regression model because we're going to estimate
                                                       ### a real number
                           mini_batch_size=200) # Here we set how many samples to look at in each iteration
                                                ##### number of rows that are used in the each mini-batch

# %% [markdown]
# Now that the hyperparameters have been set, we can ask SageMaker to fit the linear model to our data.

# %%
linear.fit({'train': s3_input_train, 'validation': s3_input_validation})
# Out:
# 2021-04-23 04:24:54 Starting - Starting the training job...
# 2021-04-23 04:24:56 Starting - Launching requested ML instances......
# 2021-04-23 04:26:01 Starting - Preparing the instances for training......
# 2021-04-23 04:27:12 Downloading - Downloading input data...
# 2021-04-23 04:27:27 Training - Downloading the training image...
# 2021-04-23 04:28:24 Uploading - Uploading generated training model
# 2021-04-23 04:28:24 Completed - Training job completed
# Docker entrypoint called with argument(s): train
# Running default environment configuration script
# [04/23/2021 04:28:10 INFO 140323432412992] Reading default configuration from /opt/amazon/lib/python3.7/site-packages/algorithm/resources/default-input.json: {'mini_batch_size': '1000', 'epochs': '15', 'feature_dim': 'auto', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false'}
# [04/23/2021 04:28:10 INFO 140323432412992] Merging with provided configuration from /opt/ml/input/config/hyperparameters.json: {'feature_dim': '13', 'predictor_type': 'regressor', 'mini_batch_size': '200'}
# [04/23/2021 04:28:10 INFO 140323432412992] Final configuration: {'mini_batch_size': '200', 'epochs': '15', 'feature_dim': '13', 'use_bias': 'true', 'binary_classifier_model_selection_criteria': 'accuracy', 'f_beta': '1.0', 'target_recall': '0.8', 'target_precision': '0.8', 'num_models': 'auto', 'num_calibration_samples': '10000000', 'init_method': 'uniform', 'init_scale': '0.07', 'init_sigma': '0.01', 'init_bias': '0.0', 'optimizer': 'auto', 'loss': 'auto', 'margin': '1.0', 'quantile': '0.5', 'loss_insensitivity': '0.01', 'huber_delta': '1.0', 'num_classes': '1', 'accuracy_top_k': '3', 'wd': 'auto', 'l1': 'auto', 'momentum': 'auto', 'learning_rate': 'auto', 'beta_1': 'auto', 'beta_2': 'auto', 'bias_lr_mult': 'auto', 'bias_wd_mult': 'auto', 'use_lr_scheduler': 'true', 'lr_scheduler_step': 'auto', 'lr_scheduler_factor': 'auto', 'lr_scheduler_minimum_lr': 'auto', 'positive_example_weight_mult': '1.0', 'balance_multiclass_weights': 'false', 'normalize_data': 'true', 'normalize_label': 'auto', 'unbias_data': 'auto', 'unbias_label': 'auto', 'num_point_for_scaler': '10000', '_kvstore': 'auto', '_num_gpus': 'auto', '_num_kv_servers': 'auto', '_log_level': 'info', '_tuning_objective_metric': '', 'early_stopping_patience': '3', 'early_stopping_tolerance': '0.001', '_enable_profiler': 'false', 'predictor_type': 'regressor'}
# [04/23/2021 04:28:10 WARNING 140323432412992] Loggers have already been setup.
# Process 1 is a worker.
# [04/23/2021 04:28:10 INFO 140323432412992] Using default worker.
# [04/23/2021 04:28:10 INFO 140323432412992] Checkpoint loading and saving are disabled.
# [04/23/2021 04:28:10 INFO 140323432412992] Create Store: local
# [04/23/2021 04:28:10 INFO 140323432412992] Scaler algorithm parameters
#  <algorithm.scaler.ScalerAlgorithmStable object at 0x7f9f42b0cb50>
# [04/23/2021 04:28:10 INFO 140323432412992] Scaling model computed with parameters:
#  {'stdev_label':
# [9.298057]
# <NDArray 1 @cpu(0)>, 'stdev_weight':
# [7.2187185e+00 2.2599337e+01 7.1321063e+00 2.2798026e-01 1.2297347e-01
#  6.9016242e-01 2.8186451e+01 2.1357639e+00 9.1911039e+00 1.7248112e+02
#  2.1736608e+00 9.3478432e+01 7.4851627e+00]
# <NDArray 13 @cpu(0)>, 'mean_label':
# [21.6615]
# <NDArray 1 @cpu(0)>, 'mean_weight':
# [3.7730215e+00 1.0747500e+01 1.1434051e+01 5.5000000e-02 5.6672400e-01
#  6.2488298e+00 7.0368004e+01 3.6773846e+00 1.0440000e+01 4.3132501e+02
#  1.8401001e+01 3.5220938e+02 1.3282200e+01]
# <NDArray 13 @cpu(0)>}
# [04/23/2021 04:28:10 INFO 140323432412992] nvidia-smi: took 0.031 seconds to run.
# [04/23/2021 04:28:10 INFO 140323432412992] nvidia-smi identified 0 GPUs.
# [04/23/2021 04:28:10 INFO 140323432412992] Number of GPUs being used: 0
# #metrics {"StartTime": 1619152090.6239445, "EndTime": 1619152090.6239927, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "Meta": "init_train_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 427.0, "count": 1, "min": 427, "max": 427}, "Total Batches Seen": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Max Records Seen Between Resets": {"sum": 227.0, "count": 1, "min": 227, "max": 227}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Number of Records Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}, "Number of Batches Since Last Reset": {"sum": 0.0, "count": 1, "min": 0, "max": 0}}}
#
# #metrics {"StartTime": 
"Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 86.49925013950893, "count": 1, "min": 86.49925013950893, "max": 86.49925013950893}}}
#
# #metrics {"StartTime": 1619152090.7389772, "EndTime": 1619152090.7389963, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 102.32034737723214, "count": 1, "min": 102.32034737723214, "max": 102.32034737723214}}}
#
# #metrics {"StartTime": 1619152090.7390537, "EndTime": 1619152090.7390714, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 100.595703125, "count": 1, "min": 100.595703125, "max": 100.595703125}}}
#
# #metrics {"StartTime": 1619152090.7391465, "EndTime": 1619152090.7391655, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 94.47746930803571, "count": 1, "min": 94.47746930803571, "max": 94.47746930803571}}}
#
# #metrics {"StartTime": 1619152090.7392228, "EndTime": 1619152090.7392404, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 118.44975062779018, "count": 1, "min": 118.44975062779018, "max": 118.44975062779018}}}
#
# #metrics {"StartTime": 1619152090.7392983, "EndTime": 1619152090.739316, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 88.25779506138393, "count": 1, "min": 88.25779506138393, "max": 88.25779506138393}}}
#
# #metrics {"StartTime": 1619152090.7393699, "EndTime": 1619152090.7393892, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 84.31358991350446, "count": 1, "min": 84.31358991350446, "max": 84.31358991350446}}}
#
# [04/23/2021 04:28:10 INFO 140323432412992] #quality_metric: host=algo-1, epoch=0, validation mse_objective <loss>=79.49974714006696
# [04/23/2021 04:28:10 INFO 140323432412992] #early_stopping_criteria_metric: host=algo-1, epoch=0, criteria=mse_objective, value=55.914524623325896
# [04/23/2021 04:28:10 INFO 140323432412992] Epoch 0: Loss improved. Updating best model
# [04/23/2021 04:28:10 INFO 140323432412992] Saving model for epoch: 0
# [04/23/2021 04:28:10 INFO 140323432412992] Saved checkpoint to "/tmp/tmplne5m2nk/mx-mod-0000.params"
# [04/23/2021 04:28:10 INFO 140323432412992] #progress_metric: host=algo-1, completed 6.666666666666667 % of epochs
# #metrics {"StartTime": 1619152090.6244733, "EndTime": 1619152090.7497113, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 0, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 654.0, "count": 1, "min": 654, "max": 654}, "Total Batches Seen": {"sum": 5.0, "count": 1, "min": 5, "max": 5}, "Max Records Seen Between Resets": {"sum": 227.0, "count": 1, "min": 227, "max": 227}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 3.0, "count": 1, "min": 3, "max": 3}, "Number of Records Since Last Reset": {"sum": 227.0, "count": 1, "min": 227, "max": 227}, "Number of Batches Since Last Reset": {"sum": 2.0, "count": 1, "min": 2, "max": 2}}}
#
# [04/23/2021 04:28:10 INFO 140323432412992] #throughput_metric: host=algo-1, train throughput=1810.299308474937 records/second
# #metrics {"StartTime": 1619152090.7899277, "EndTime": 1619152090.7899787, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"train_mse_objective": {"sum": 0.9257827758789062, "count": 1, "min": 0.9257827758789062, "max": 0.9257827758789062}}}
#
# #metrics {"StartTime": 1619152090.7900422, "EndTime": 1619152090.7900553, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"train_mse_objective": {"sum": 0.8197846221923828, "count": 1, "min": 0.8197846221923828, "max": 0.8197846221923828}}}
#
# #metrics {"StartTime": 1619152090.7901084, "EndTime": 1619152090.7901266, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"train_mse_objective": {"sum": 1.2834861755371094, "count": 1, "min": 1.2834861755371094, "max": 1.2834861755371094}}}
#
# #metrics {"StartTime": 1619152090.7901843, "EndTime": 1619152090.7902005, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"train_mse_objective": {"sum": 0.8288362884521484, "count": 1, "min": 0.8288362884521484, "max": 0.8288362884521484}}}
#
# #metrics {"StartTime": 1619152090.7902544, "EndTime": 1619152090.7902715, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"train_mse_objective": {"sum": 0.7427228546142578, "count": 1, "min": 0.7427228546142578, "max": 0.7427228546142578}}}
#
# #metrics {"StartTime": 1619152090.7903256, "EndTime": 1619152090.7903426, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"train_mse_objective": {"sum": 0.572194709777832, "count": 1, "min": 0.572194709777832, "max": 0.572194709777832}}}
#
# #metrics {"StartTime": 1619152090.7903984, "EndTime": 1619152090.7904167, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"train_mse_objective": {"sum": 0.6639991760253906, "count": 1, "min": 0.6639991760253906, "max": 0.6639991760253906}}}
#
# #metrics {"StartTime": 1619152090.7904656, "EndTime": 1619152090.790476, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"train_mse_objective": {"sum": 0.6390641021728516, "count": 1, "min": 0.6390641021728516, "max": 0.6390641021728516}}}
#
# #metrics {"StartTime": 1619152090.790515, "EndTime": 1619152090.790529, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"train_mse_objective": {"sum": 0.8724546813964844, "count": 1, "min": 0.8724546813964844, "max": 0.8724546813964844}}}
#
# #metrics {"StartTime": 1619152090.7905803, "EndTime": 1619152090.7905982, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"train_mse_objective": {"sum": 1.3520176696777344, "count": 1, "min": 1.3520176696777344, "max": 1.3520176696777344}}}
#
# #metrics {"StartTime": 1619152090.7907228, "EndTime": 1619152090.7907436, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 10}, "Metrics": {"train_mse_objective": {"sum": 0.8117084503173828, "count": 1, "min": 0.8117084503173828, "max": 0.8117084503173828}}}
#
# #metrics {"StartTime": 1619152090.79079, "EndTime": 1619152090.7908058, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 11}, "Metrics": {"train_mse_objective": {"sum": 1.0509733581542968, "count": 1, "min": 1.0509733581542968, "max": 1.0509733581542968}}}
#
# #metrics {"StartTime": 1619152090.7908692, "EndTime": 1619152090.7908878, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 12}, "Metrics": {"train_mse_objective": {"sum": 0.6857794952392579, "count": 1, "min": 0.6857794952392579, "max": 0.6857794952392579}}}
#
# #metrics {"StartTime": 1619152090.7909467, "EndTime": 1619152090.7909644, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 13}, "Metrics": {"train_mse_objective": {"sum": 0.6943463897705078, "count": 1, "min": 0.6943463897705078, "max": 0.6943463897705078}}}
#
# #metrics {"StartTime": 1619152090.791031, "EndTime": 1619152090.7910504, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 14}, "Metrics": {"train_mse_objective": {"sum": 0.8401862335205078, "count": 1, "min": 0.8401862335205078, "max": 0.8401862335205078}}}
#
# #metrics {"StartTime": 1619152090.7911162, "EndTime": 1619152090.7911348, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 15}, "Metrics": {"train_mse_objective": {"sum": 0.6039910125732422, "count": 1, "min": 0.6039910125732422, "max": 0.6039910125732422}}}
#
# #metrics {"StartTime": 1619152090.791187, "EndTime": 1619152090.7912054, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 16}, "Metrics": {"train_mse_objective": {"sum": 0.9862550354003906, "count": 1, "min": 0.9862550354003906, "max": 0.9862550354003906}}}
#
# #metrics {"StartTime": 1619152090.791266, "EndTime": 1619152090.7912843, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 17}, "Metrics": {"train_mse_objective": {"sum": 0.8112855529785157, "count": 1, "min": 0.8112855529785157, "max": 0.8112855529785157}}}
#
# #metrics {"StartTime": 1619152090.791344, "EndTime": 1619152090.7913623, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 18}, "Metrics": {"train_mse_objective": {"sum": 1.1522813415527344, "count": 1, "min": 1.1522813415527344, "max": 1.1522813415527344}}}
#
# #metrics {"StartTime": 1619152090.7914176, "EndTime": 1619152090.7914305, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 19}, "Metrics": {"train_mse_objective": {"sum": 0.9791262054443359, "count": 1, "min": 0.9791262054443359, "max": 0.9791262054443359}}}
#
# #metrics {"StartTime": 1619152090.7914617, "EndTime": 1619152090.7914762, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 20}, "Metrics": {"train_mse_objective": {"sum": 0.837431411743164, "count": 1, "min": 0.837431411743164, "max": 0.837431411743164}}}
#
# #metrics {"StartTime": 1619152090.7915344, "EndTime": 1619152090.7915523, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 21}, "Metrics": {"train_mse_objective": {"sum": 0.5999068069458008, "count": 1, "min": 0.5999068069458008, "max": 0.5999068069458008}}}
#
# #metrics {"StartTime": 1619152090.7916086, "EndTime": 1619152090.7916265, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 22}, "Metrics": {"train_mse_objective": {"sum": 0.7022990417480469, "count": 1, "min": 0.7022990417480469, "max": 0.7022990417480469}}}
#
# #metrics {"StartTime": 1619152090.7916849, "EndTime": 1619152090.7917025, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 23}, "Metrics": {"train_mse_objective": {"sum": 0.7109664916992188, "count": 1, "min": 0.7109664916992188, "max": 0.7109664916992188}}}
#
# #metrics {"StartTime": 1619152090.7917588, "EndTime": 1619152090.7917752, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 24}, "Metrics": {"train_mse_objective": {"sum": 0.9650514221191406, "count": 1, "min": 0.9650514221191406, "max": 0.9650514221191406}}}
#
# #metrics {"StartTime": 1619152090.791828, "EndTime": 1619152090.7918456, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 25}, "Metrics": {"train_mse_objective": {"sum": 0.9479328155517578, "count": 1, "min": 0.9479328155517578, "max": 0.9479328155517578}}}
#
# #metrics {"StartTime": 1619152090.7919052, "EndTime": 1619152090.791923, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 26}, "Metrics": {"train_mse_objective": {"sum": 1.2087703704833985, "count": 1, "min": 1.2087703704833985, "max": 1.2087703704833985}}}
#
# #metrics {"StartTime": 1619152090.791977, "EndTime": 1619152090.7919939, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 27}, "Metrics": {"train_mse_objective": {"sum": 1.0998611450195312, "count": 1, "min": 1.0998611450195312, "max": 1.0998611450195312}}}
#
# #metrics {"StartTime": 1619152090.792049, "EndTime": 1619152090.7920663, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 1.0399664306640626, "count": 1, "min": 1.0399664306640626, "max": 1.0399664306640626}}}
#
# #metrics {"StartTime": 1619152090.7921195, "EndTime": 1619152090.7921371, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.3024275207519531, "count": 1, "min": 1.3024275207519531, "max": 1.3024275207519531}}}
#
# #metrics {"StartTime": 1619152090.7921844, "EndTime": 1619152090.7922013, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 0.8734777069091797, "count": 1, "min": 0.8734777069091797, "max": 0.8734777069091797}}}
#
# #metrics {"StartTime": 1619152090.7922463, "EndTime": 1619152090.792262, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.8989571380615234, "count": 1, "min": 0.8989571380615234, "max": 0.8989571380615234}}}
#
# [04/23/2021 04:28:10 INFO 140323432412992] #quality_metric: host=algo-1, epoch=1, train mse_objective <loss>=0.9257827758789062
# #metrics {"StartTime": 1619152090.8569496, "EndTime": 1619152090.857034, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 74.30150495256696, "count": 1, "min": 74.30150495256696, "max": 74.30150495256696}}}
#
# #metrics {"StartTime": 1619152090.857129, "EndTime": 1619152090.8571491, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 71.78290230887276, "count": 1, "min": 71.78290230887276, "max": 71.78290230887276}}}
#
# #metrics {"StartTime": 1619152090.857206, "EndTime": 1619152090.8572218, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 105.60544259207589, "count": 1, "min": 105.60544259207589, "max": 105.60544259207589}}}
#
# #metrics {"StartTime": 1619152090.8572726, "EndTime": 1619152090.8572876, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 68.44712175641742, "count": 1, "min": 68.44712175641742, "max": 68.44712175641742}}}
#
# #metrics {"StartTime": 1619152090.8573415, "EndTime": 1619152090.8573565, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 82.08273751395089, "count": 1, "min": 82.08273751395089, "max": 82.08273751395089}}}
#
# #metrics {"StartTime": 1619152090.8574076, "EndTime": 1619152090.857422, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 82.28579275948661, "count": 1, "min": 82.28579275948661, "max": 82.28579275948661}}}
#
# #metrics {"StartTime": 1619152090.857496, "EndTime": 1619152090.8575125, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 91.03600202287946, "count": 1, "min": 91.03600202287946, "max": 91.03600202287946}}}
#
# #metrics {"StartTime": 1619152090.8575618, "EndTime": 1619152090.8575766, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 90.20025634765625, "count": 1, "min": 90.20025634765625, "max": 90.20025634765625}}}
#
# #metrics {"StartTime": 1619152090.8576252, "EndTime": 1619152090.8576398, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 79.11220877511161, "count": 1, "min": 79.11220877511161, "max": 79.11220877511161}}}
#
# #metrics {"StartTime": 1619152090.857697, "EndTime": 1619152090.8577123, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 9}, "Metrics": {"validation_mse_objective": {"sum":
"Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 1, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 90.59626988002232, "count": 1, "min": 90.59626988002232, "max": 90.59626988002232}}}
#
# ...
#
# #metrics {"StartTime": 1619152092.0242887, "EndTime": 1619152092.024308, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 28}, "Metrics": {"train_mse_objective": {"sum": 0.949928207397461, "count": 1, "min": 0.949928207397461, "max": 0.949928207397461}}}
#
# #metrics {"StartTime": 1619152092.0243661, "EndTime": 1619152092.0243852, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 29}, "Metrics": {"train_mse_objective": {"sum": 1.0158882141113281, "count": 1, "min": 1.0158882141113281, "max": 1.0158882141113281}}}
#
# #metrics {"StartTime": 1619152092.024443, "EndTime": 1619152092.024461, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 30}, "Metrics": {"train_mse_objective": {"sum": 0.8675319671630859, "count": 1, "min": 0.8675319671630859, "max": 0.8675319671630859}}}
#
# #metrics {"StartTime": 1619152092.0245173, "EndTime": 1619152092.0245368, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 31}, "Metrics": {"train_mse_objective": {"sum": 0.9576913452148438, "count": 1, "min": 0.9576913452148438, "max": 0.9576913452148438}}}
#
# [04/23/2021 04:28:12 INFO 140323432412992] #quality_metric: host=algo-1, epoch=10, train mse_objective <loss>=0.6081898880004882
# #metrics {"StartTime": 1619152092.0972955, "EndTime": 1619152092.0973878, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 0}, "Metrics": {"validation_mse_objective": {"sum": 52.208583286830354, "count": 1, "min": 52.208583286830354, "max": 52.208583286830354}}}
#
# #metrics {"StartTime": 1619152092.0975304, "EndTime": 1619152092.0975544, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 1}, "Metrics": {"validation_mse_objective": {"sum": 53.05797903878348, "count": 1, "min": 53.05797903878348, "max": 53.05797903878348}}}
#
# #metrics {"StartTime": 1619152092.097627, "EndTime": 1619152092.0976462, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 2}, "Metrics": {"validation_mse_objective": {"sum": 68.2236807686942, "count": 1, "min": 68.2236807686942, "max": 68.2236807686942}}}
#
# #metrics {"StartTime": 1619152092.0977075, "EndTime": 1619152092.0977254, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 3}, "Metrics": {"validation_mse_objective": {"sum": 51.86010306222098, "count": 1, "min": 51.86010306222098, "max": 51.86010306222098}}}
#
# #metrics {"StartTime": 1619152092.0977817, "EndTime": 1619152092.0978003, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 4}, "Metrics": {"validation_mse_objective": {"sum": 45.06232125418527, "count": 1, "min": 45.06232125418527, "max": 45.06232125418527}}}
#
# #metrics {"StartTime": 1619152092.0978587, "EndTime": 1619152092.0978754, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 5}, "Metrics": {"validation_mse_objective": {"sum": 41.99013410295759, "count": 1, "min": 41.99013410295759, "max": 41.99013410295759}}}
#
# #metrics {"StartTime": 1619152092.097926, "EndTime": 1619152092.0979402, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 6}, "Metrics": {"validation_mse_objective": {"sum": 43.99206978934152, "count": 1, "min": 43.99206978934152, "max": 43.99206978934152}}}
#
# #metrics {"StartTime": 1619152092.0979896, "EndTime": 1619152092.0980067, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 7}, "Metrics": {"validation_mse_objective": {"sum": 47.47462681361607, "count": 1, "min": 47.47462681361607, "max": 47.47462681361607}}}
#
# #metrics {"StartTime": 1619152092.09806, "EndTime": 1619152092.0980754, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 8}, "Metrics": {"validation_mse_objective": {"sum": 59.74295915876116, "count": 1, "min": 59.74295915876116, "max": 59.74295915876116}}}
#
# #metrics {"StartTime": 1619152092.098126, "EndTime": 1619152092.0981421, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 9}, "Metrics": {"validation_mse_objective": {"sum": 73.18260846819196, "count": 1, "min": 73.18260846819196, "max": 73.18260846819196}}}
#
# #metrics {"StartTime": 1619152092.0981975, "EndTime": 1619152092.098214, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 10}, "Metrics": {"validation_mse_objective": {"sum": 54.78891863141741, "count": 1, "min": 54.78891863141741, "max": 54.78891863141741}}}
#
# #metrics {"StartTime": 1619152092.0982673, "EndTime": 1619152092.0982842, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 11}, "Metrics": {"validation_mse_objective": {"sum": 65.16932460239956, "count": 1, "min": 65.16932460239956, "max": 65.16932460239956}}}
#
# #metrics {"StartTime": 1619152092.0983384, "EndTime": 1619152092.098356, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 12}, "Metrics": {"validation_mse_objective": {"sum": 47.157379150390625, "count": 1, "min": 47.157379150390625, "max": 47.157379150390625}}}
#
# #metrics {"StartTime": 1619152092.0984085, "EndTime": 1619152092.0984251, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 13}, "Metrics": {"validation_mse_objective": {"sum": 45.244253976004465, "count": 1, "min": 45.244253976004465, "max": 45.244253976004465}}}
#
# #metrics {"StartTime": 1619152092.098483, "EndTime": 1619152092.0985005, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 14}, "Metrics": {"validation_mse_objective": {"sum": 42.21783883231027, "count": 1, "min": 42.21783883231027, "max": 42.21783883231027}}}
#
# #metrics {"StartTime": 1619152092.098553, "EndTime": 1619152092.0985703, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 15}, "Metrics": {"validation_mse_objective": {"sum": 42.78141130719866, "count": 1, "min": 42.78141130719866, "max": 42.78141130719866}}}
#
# #metrics {"StartTime": 1619152092.098623, "EndTime": 1619152092.0986388, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 16}, "Metrics": {"validation_mse_objective": {"sum": 58.26221139090402, "count": 1, "min": 58.26221139090402, "max": 58.26221139090402}}}
#
# #metrics {"StartTime": 1619152092.098687, "EndTime": 1619152092.0987034, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 17}, "Metrics": {"validation_mse_objective": {"sum": 54.185743059430806, "count": 1, "min": 54.185743059430806, "max": 54.185743059430806}}}
#
# #metrics {"StartTime": 1619152092.0987577, "EndTime": 1619152092.0987732, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 18}, "Metrics": {"validation_mse_objective": {"sum": 71.08612932477679, "count": 1, "min": 71.08612932477679, "max": 71.08612932477679}}}
#
# #metrics {"StartTime": 1619152092.0988178, "EndTime": 1619152092.0988314, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 19}, "Metrics": {"validation_mse_objective": {"sum": 60.574475969587056, "count": 1, "min": 60.574475969587056, "max": 60.574475969587056}}}
#
# #metrics {"StartTime": 1619152092.0988796, "EndTime": 1619152092.0988934, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 20}, "Metrics": {"validation_mse_objective": {"sum": 35.68221173967634, "count": 1, "min": 35.68221173967634, "max": 35.68221173967634}}}
#
# #metrics {"StartTime": 1619152092.0989392, "EndTime": 1619152092.098953, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 21}, "Metrics": {"validation_mse_objective": {"sum": 34.874110630580354, "count": 1, "min": 34.874110630580354, "max": 34.874110630580354}}}
#
# #metrics {"StartTime": 1619152092.0990062, "EndTime": 1619152092.0990226, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 22}, "Metrics": {"validation_mse_objective": {"sum": 36.576808384486604, "count": 1, "min": 36.576808384486604, "max": 36.576808384486604}}}
#
# #metrics {"StartTime": 1619152092.0990736, "EndTime": 1619152092.0990894, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 23}, "Metrics": {"validation_mse_objective": {"sum": 38.960728236607146, "count": 1, "min": 38.960728236607146, "max": 38.960728236607146}}}
#
# #metrics {"StartTime": 1619152092.099144, "EndTime": 1619152092.0991607, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 24}, "Metrics": {"validation_mse_objective": {"sum": 89.01587785993304, "count": 1, "min": 89.01587785993304, "max": 89.01587785993304}}}
#
# #metrics {"StartTime": 1619152092.0992162, "EndTime": 1619152092.0992327, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 25}, "Metrics": {"validation_mse_objective": {"sum": 85.73157610212054, "count": 1, "min": 85.73157610212054, "max": 85.73157610212054}}}
#
# #metrics {"StartTime": 1619152092.099283, "EndTime": 1619152092.0993006, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 26}, "Metrics": {"validation_mse_objective": {"sum": 83.18738664899554, "count": 1, "min": 83.18738664899554, "max": 83.18738664899554}}}
#
# #metrics {"StartTime": 1619152092.0993533, "EndTime": 1619152092.0993693, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 27}, "Metrics": {"validation_mse_objective": {"sum": 85.75040108816964, "count": 1, "min": 85.75040108816964, "max": 85.75040108816964}}}
#
# #metrics {"StartTime": 1619152092.099421, "EndTime": 1619152092.0994384, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 28}, "Metrics": {"validation_mse_objective": {"sum": 85.09270368303571, "count": 1, "min": 85.09270368303571, "max": 85.09270368303571}}}
#
# #metrics {"StartTime": 1619152092.0994952, "EndTime": 1619152092.099512, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 29}, "Metrics": {"validation_mse_objective": {"sum": 84.28107561383929, "count": 1, "min": 84.28107561383929, "max": 84.28107561383929}}}
#
# #metrics {"StartTime": 1619152092.099568, "EndTime": 1619152092.0995855, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 30}, "Metrics": {"validation_mse_objective": {"sum": 81.74827357700893, "count": 1, "min": 81.74827357700893, "max": 81.74827357700893}}}
#
# #metrics {"StartTime": 1619152092.099639, "EndTime": 1619152092.099656, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "model": 31}, "Metrics": {"validation_mse_objective": {"sum": 87.25059291294643, "count": 1, "min": 87.25059291294643, "max": 87.25059291294643}}}
#
# [04/23/2021 04:28:12 INFO 140323432412992] #quality_metric: host=algo-1, epoch=10, validation mse_objective <loss>=52.208583286830354
# [04/23/2021 04:28:12 INFO 140323432412992] #early_stopping_criteria_metric: host=algo-1, epoch=10, criteria=mse_objective, value=34.874110630580354
# [04/23/2021 04:28:12 INFO 140323432412992] Saving model for epoch: 10
# [04/23/2021 04:28:12 INFO 140323432412992] Saved checkpoint to "/tmp/tmpkycx26ri/mx-mod-0000.params"
# [04/23/2021 04:28:12 INFO 140323432412992] Early stop condition met. Stopping training.
# [04/23/2021 04:28:12 INFO 140323432412992] #progress_metric: host=algo-1, completed 100 % epochs
# #metrics {"StartTime": 1619152091.977577, "EndTime": 1619152092.108616, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training", "epoch": 10, "Meta": "training_data_iter"}, "Metrics": {"Total Records Seen": {"sum": 2924.0, "count": 1, "min": 2924, "max": 2924}, "Total Batches Seen": {"sum": 25.0, "count": 1, "min": 25, "max": 25}, "Max Records Seen Between Resets": {"sum": 227.0, "count": 1, "min": 227, "max": 227}, "Max Batches Seen Between Resets": {"sum": 2.0, "count": 1, "min": 2, "max": 2}, "Reset Count": {"sum": 13.0, "count": 1, "min": 13, "max": 13}, "Number of Records Since Last Reset": {"sum": 227.0, "count": 1, "min": 227, "max": 227}, "Number of Batches Since Last Reset": {"sum": 2.0, "count": 1, "min": 2, "max": 2}}}
#
# [04/23/2021 04:28:12 INFO 140323432412992] #throughput_metric: host=algo-1, train throughput=1730.2762642590906 records/second
# [04/23/2021 04:28:12 WARNING 140323432412992] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [04/23/2021 04:28:12 WARNING 140323432412992] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [04/23/2021 04:28:12 INFO 140323432412992] #early_stopping_criteria_metric: host=algo-1, epoch=10, criteria=mse_objective, value=34.874110630580354
# [04/23/2021 04:28:12 INFO 140323432412992] #validation_score (algo-1) : ('mse_objective', 26.458199637276785)
# [04/23/2021 04:28:12 INFO 140323432412992] #validation_score (algo-1) : ('mse', 26.458199637276785)
# [04/23/2021 04:28:12 INFO 140323432412992] #validation_score (algo-1) : ('absolute_loss', 3.8529150826590404)
# [04/23/2021 04:28:12 INFO 140323432412992] #quality_metric: host=algo-1, validation mse_objective <loss>=26.458199637276785
# [04/23/2021 04:28:12 INFO 140323432412992] #quality_metric: host=algo-1, validation mse <loss>=26.458199637276785
# [04/23/2021 04:28:12 INFO 140323432412992] #quality_metric: host=algo-1, validation absolute_loss <loss>=3.8529150826590404
# [04/23/2021 04:28:12 INFO 140323432412992] Best model found for hyperparameters: {"optimizer": "adam", "learning_rate": 0.1, "wd": 0.0001, "l1": 0.0, "lr_scheduler_step": 10, "lr_scheduler_factor": 0.99, "lr_scheduler_minimum_lr": 1e-05}
# [04/23/2021 04:28:12 INFO 140323432412992] Saved checkpoint to "/tmp/tmp7aveqrgf/mx-mod-0000.params"
# [04/23/2021 04:28:12 INFO 140323432412992] Test data is not provided.
# #metrics {"StartTime": 1619152090.4542618, "EndTime": 1619152092.1915815, "Dimensions": {"Algorithm": "Linear Learner", "Host": "algo-1", "Operation": "training"}, "Metrics": {"initialize.time": {"sum": 169.34776306152344, "count": 1, "min": 169.34776306152344, "max": 169.34776306152344}, "epochs": {"sum": 15.0, "count": 1, "min": 15, "max": 15}, "check_early_stopping.time": {"sum": 6.413698196411133, "count": 12, "min": 0.1938343048095703, "max": 1.4638900756835938}, "update.time": {"sum": 1420.6116199493408, "count": 11, "min": 113.6012077331543, "max": 149.11794662475586}, "finalize.time": {"sum": 74.9979019165039, "count": 1, "min": 74.9979019165039, "max": 74.9979019165039}, "setuptime": {"sum": 24.31201934814453, "count": 1, "min": 24.31201934814453, "max": 24.31201934814453}, "totaltime": {"sum": 1958.923578262329, "count": 1, "min": 1958.923578262329, "max": 1958.923578262329}}}
#
# Training seconds: 72
# Billable seconds: 72

# %% [markdown]
# ## Step 6 (B): Deploy the trained model
#
# Similar to the XGBoost model, now that we've fit the model we need to deploy it. Also like the XGBoost model, we will use the lower level approach so that we have more control over the endpoint that gets created.
#
# ### Build the model
#
# Of course, before we can deploy the model, we need to first create it. The `fit` method that we used earlier created some model artifacts and we can use these to construct a model object.

# %%
###### First, we create a model object inside of Sagemaker by describing where the model artifacts are being stored and 
###### which container should be used to perform inference


# First, we create a unique model name
linear_model_name = "boston-update-linear-model" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# We also need to tell SageMaker which container should be used for inference and where it should
# retrieve the model artifacts from. In our case, the linear-learner container that we used for training
# can also be used for inference.
linear_primary_container = {
    "Image": linear_container, ##### which container should be used to perform inference
    "ModelDataUrl": linear.model_data
}

# And lastly we construct the SageMaker model
linear_model_info = session.sagemaker_client.create_model(
                                ModelName = linear_model_name,
                                ExecutionRoleArn = role,
                                PrimaryContainer = linear_primary_container)

# %% [markdown]
# ### Create the endpoint configuration
#
# Once we have the model we can start putting together the endpoint by creating an endpoint configuration.

# %%
######## Second, We can create an endpoint configuration ###########


# As before, we need to give our endpoint configuration a name which should be unique
linear_endpoint_config_name = "boston-linear-endpoint-config-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we ask SageMaker to construct the endpoint configuration
linear_endpoint_config_info = session.sagemaker_client.create_endpoint_config(
                            EndpointConfigName = linear_endpoint_config_name,
                            ProductionVariants = [{
                                "InstanceType": "ml.m4.xlarge",
                                "InitialVariantWeight": 1,  ##### we have a single production variant
                                "InitialInstanceCount": 1,
                                "ModelName": linear_model_name, #### we call the production variant the linear model
                                "VariantName": "Linear-Model"
                            }])

# %% [markdown]
# ### Deploy the endpoint
#
# Now that the endpoint configuration has been created, we can ask SageMaker to build our endpoint.
#
# **Note:** This is a friendly (repeated) reminder that you are about to deploy an endpoint. Make sure that you shut it down once you've finished with it!

# %%
######### Third, we can ask SageMaker to create an endpoint with those properties #############


# Again, we need a unique name for our endpoint
endpoint_name = "boston-update-endpoint-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we can deploy our endpoint
endpoint_info = session.sagemaker_client.create_endpoint(
                    EndpointName = endpoint_name,
                    EndpointConfigName = linear_endpoint_config_name)

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)
# Out:
# -------------!

# %% [markdown]
# ## Step 7 (B): Use the model
#
# Just like with the XGBoost model, we will send some data to our endpoint to make sure that it is working properly. An important note is that the output format for the linear model is different from the XGBoost model.

# %%
response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[0]))) ### we can send the first row of 
                                                ### our test data which we do by first serializing it and then sending it off
                                                ### to our endpoint

# %%
pprint(response)  ##### and just like in the XGBoost case, we get a JSON object as a response
# Out:
# {'Body': <botocore.response.StreamingBody object at 0x7fbe86d5a7b8>,
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'Linear-Model',
#  'ResponseMetadata': {'HTTPHeaders': {'content-length': '47',
#                                       'content-type': 'application/json',
#                                       'date': 'Fri, 23 Apr 2021 04:35:08 GMT',
#                                       'x-amzn-invoked-production-variant': 'Linear-Model',
#                                       'x-amzn-requestid': '95f612c0-47f5-4b6d-abfa-66bbc8419cb7'},
#                       'HTTPStatusCode': 200,
#                       'RequestId': '95f612c0-47f5-4b6d-abfa-66bbc8419cb7',
#                       'RetryAttempts': 0}}

# %%
result = response['Body'].read().decode("utf-8") ### we read in the body object and turn it back to into a string

# %%
pprint(result)
# Out:
# '{"predictions": [{"score": 40.05923843383789}]}'

# %%
Y_test.values[0] #### this is the ture value
# Out:
# array([48.5])

# %% [markdown]
# ## Shut down the endpoint
#
# Now that we know that the Linear model's endpoint works, we can shut it down.

# %%
session.sagemaker_client.delete_endpoint(EndpointName = endpoint_name)
# Out:
# {'ResponseMetadata': {'RequestId': '71e14eaa-356a-4a96-9a4d-7db848380178',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '71e14eaa-356a-4a96-9a4d-7db848380178',
#    'content-type': 'application/x-amz-json-1.1',
#    'content-length': '0',
#    'date': 'Fri, 23 Apr 2021 04:35:07 GMT'},
#   'RetryAttempts': 0}}

# %% [markdown]
# ## Step 6 (C): Deploy a combined model
#
# So far we've constructed two separate models which we could deploy and use. Before we talk about how we can change a deployed endpoint from one configuration to another, let's consider a slightly different situation. Suppose that before we switch from using only the XGBoost model to only the Linear model, we first want to do something like an A-B test, where we send some of the incoming data to the XGBoost model and some of the data to the Linear model.
#
# Fortunately, SageMaker provides this functionality. And to actually get SageMaker to do this for us is not too different from deploying a model in the way that we've already done. The only difference is that we need to list more than one model in the production variants parameter of the endpoint configuration.
#
# A reasonable question to ask is, how much data is sent to each of the models that I list in the production variants parameter? The answer is that it depends on the weight set for each model.
#
# Suppose that we have $k$ models listed in the production variants and that each model $i$ is assigned the weight $w_i$. Then each model $i$ will receive $w_i / W$ of the traffic where $W = \sum_{i} w_i$.
#
# In our case, since we have two models, the linear model and the XGBoost model, and each model has weight 1, we see that each model will get 1 / (1 + 1) = 1/2 of the data sent to the endpoint.

# %%
#### we perform an A-B test which is we create a new endpoint that receives a bunch of data, and then the endpoint decides
#### which of the two models to send that data to.

#### We can do that when we set up an endpoint configuration by listing each model as its own product variant

# As before, we need to give our endpoint configuration a name which should be unique
combined_endpoint_config_name = "boston-combined-endpoint-config-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

#### And then we ask SageMaker to construct the endpoint configuration with two production variants
combined_endpoint_config_info = session.sagemaker_client.create_endpoint_config(
                            EndpointConfigName = combined_endpoint_config_name,
                            ProductionVariants = [
                                { # First we include the linear model
                                    "InstanceType": "ml.m4.xlarge",
                                    "InitialVariantWeight": 1,
                                    "InitialInstanceCount": 1,
                                    "ModelName": linear_model_name,
                                    "VariantName": "Linear-Model"
                                }, { # And next we include the xgb model
                                    "InstanceType": "ml.m4.xlarge",
                                    "InitialVariantWeight": 1,
                                    "InitialInstanceCount": 1,
                                    "ModelName": xgb_model_name,
                                    "VariantName": "XGB-Model"
                                }])

###### The proportion of the data that we send to the first model will be that model's weight divided by the total weights
###### In this case, the total weights is 2, 1/2 is the half data, so half data will be send to the linear model #########
###### and the other half of the data will be send to the XGBoost model
##############################################################################################################################

# %% [markdown]
# Now that we've created the endpoint configuration, we can ask SageMaker to construct the endpoint.
#
# **Note:** This is a friendly (repeated) reminder that you are about to deploy an endpoint. Make sure that you shut it down once you've finished with it!

# %%
####### Once we create the endpoint configuration, we can ask SageMaker to create an endpoint with those properties


# Again, we need a unique name for our endpoint
endpoint_name = "boston-update-endpoint-" + strftime("%Y-%m-%d-%H-%M-%S", gmtime())

# And then we can deploy our endpoint
endpoint_info = session.sagemaker_client.create_endpoint(
                    EndpointName = endpoint_name,
                    EndpointConfigName = combined_endpoint_config_name)
# Out:
# ---------------------------------------------------------------------------
# ResourceLimitExceeded                     Traceback (most recent call last)
# <ipython-input-36-f751cd4921f3> in <module>
#       8 endpoint_info = session.sagemaker_client.create_endpoint(
#       9                     EndpointName = endpoint_name,
# ---> 10                     EndpointConfigName = combined_endpoint_config_name)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     355                     "%s() only accepts keyword arguments." % py_operation_name)
#     356             # The "self" in this scope is referring to the BaseClient.
# --> 357             return self._make_api_call(operation_name, kwargs)
#     358
#     359         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/pytorch_p36/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     674             error_code = parsed_response.get("Error", {}).get("Code")
#     675             error_class = self.exceptions.from_code(error_code)
# --> 676             raise error_class(parsed_response, operation_name)
#     677         else:
#     678             return parsed_response
#
# ResourceLimitExceeded: An error occurred (ResourceLimitExceeded) when calling the CreateEndpoint operation: The account-level service limit 'Number of instances across active endpoints' is 2 Instances, with current utilization of 1 Instances and a request delta of 2 Instances. Please contact AWS support to request an increase for this limit.

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)

# %% [markdown]
# ## Step 7 (C): Use the model
#
# Now that we've constructed an endpoint which sends data to both the XGBoost model and the linear model we can send some data to the endpoint and see what sort of results we get back.

# %%
response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[0]))) ### we will send just the first
                                                #### row of our test data after we serialize it to this new conbined endpoint
pprint(response)

# %% [markdown]
# Since looking at a single response doesn't give us a clear look at what is happening, we can instead take a look at a few different responses to our endpoint

# %%
##### Next, let's take a look at sending the first 10 rows of our test dataset to the endpoint, and print response from
##### each of those calls

for rec in range(10):
    response = session.sagemaker_runtime_client.invoke_endpoint(
                                                EndpointName = endpoint_name,
                                                ContentType = 'text/csv',
                                                Body = ','.join(map(str, X_test.values[rec])))
    pprint(response)
    result = response['Body'].read().decode("utf-8")
    print(result)
    print(Y_test.values[rec])

# %% [markdown]
# If at some point we aren't sure about the properties of a deployed endpoint, we can use the `describe_endpoint` function to get SageMaker to return a description of the deployed endpoint.

# %%
pprint(session.sagemaker_client.describe_endpoint(EndpointName=endpoint_name))

# %% [markdown]
# ## Updating an Endpoint
#
# Now suppose that we've done our A-B test and the new linear model is working well enough. What we'd like to do now is to switch our endpoint from sending data to both the XGBoost model and the linear model to sending data only to the linear model.
#
# Of course, we don't really want to shut down the endpoint to do this as doing so would interrupt service to whoever depends on our endpoint. Instead, we can ask SageMaker to **update** an endpoint to a new endpoint configuration.
#
# What is actually happening is that SageMaker will set up a new endpoint with the new characteristics. Once this new endpoint is running, SageMaker will switch the old endpoint so that it now points at the newly deployed model, making sure that this happens seamlessly in the background.

# %%
### we need to specify which endpoint we'd like to update and what endpoint configuration we would like to that endpoint
### to look like once the update has finished
session.sagemaker_client.update_endpoint(EndpointName=endpoint_name, EndpointConfigName=linear_endpoint_config_name)

# %% [markdown]
# To get a glimpse at what is going on, we can ask SageMaker to describe our in-use endpoint now, before the update process has completed. When we do so, we can see that the in-use endpoint still has the same characteristics it had before.

# %%
pprint(session.sagemaker_client.describe_endpoint(EndpointName=endpoint_name))

# %% [markdown]
# If we now wait for the update process to complete, and then ask SageMaker to describe the endpoint, it will return the characteristics of the new endpoint configuration.

# %%
endpoint_dec = session.wait_for_endpoint(endpoint_name)

# %%
pprint(session.sagemaker_client.describe_endpoint(EndpointName=endpoint_name))

# %% [markdown]
# ## Shut down the endpoint
#
# Now that we've finished, we need to make sure to shut down the endpoint.

# %%
session.sagemaker_client.delete_endpoint(EndpointName = endpoint_name)

# %% [markdown]
# ## Optional: Clean up
#
# The default notebook instance on SageMaker doesn't have a lot of excess disk space available. As you continue to complete and execute notebooks you will eventually fill up this disk space, leading to errors which can be difficult to diagnose. Once you are completely finished using a notebook it is a good idea to remove the files that you created along the way. Of course, you can do this from the terminal or from the notebook hub if you would like. The cell below contains some commands to clean up the created files from within the notebook.

# %%
# First we will remove all of the files contained in the data_dir directory
# !rm $data_dir/*

# And then we delete the directory itself
# !rmdir $data_dir
